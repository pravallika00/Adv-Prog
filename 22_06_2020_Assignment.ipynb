# %% [markdown]
# <a href="https://colab.research.google.com/github/pravallika00/Adv-Prog/blob/master/22_06_2020_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CSE-221710307021-Pravallika

# %% [markdown]
# #1) Write a program in C to insert a new node at the beginning of a Singly Linked List.

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct node{
	int data;
	struct node *next;
}*S,*L,*C,*P;

void insertNode();
void deleteNode();
void display();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1)
	{
		printf("\n Single linked list ");
		printf("\n 1.Insert ");
		printf("\n 2.Delete ");
	    printf("\n 3.Display ");
		printf("\n 4.Exit ");	
		printf("\n Enter Your Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();
			break;
			case 3: display();
			break;
			case 4: printf("\n program is terminating ");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode()
{
	struct node *nn;
	nn = (struct node *)malloc(sizeof(struct node));
	scanf("%d",&nn->data);
	nn->next = NULL;
	if(S == NULL)
	{
		S = L = nn;
	}
	else
	{
		nn->next = S;
		S = nn;
	}
	
	printf("\n node is inserted at the start");
	getch();
	
}
void deleteNode()
{
	
}
void display()
{
	if(S == NULL)
	{
		printf("\n linked list is empty ");
	}
	else
	{
		printf("\n nodes in the linked list ");
		for(C = S;C!=NULL;C=C->next)
		{
			printf("%d",C->data);
		}
		getch();
	}
	
}

# %% [markdown]
# #2) Write a program in C to insert a new node at the end of a Singly Linked List.

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>
struct node{
	int data;
	struct node *next;
};
struct node *head;  

void insertNode();
void deleteNode();
void display();

int main()
{
	int x;
	S = L = C = P = NULL;
	while(1)
	{
		printf("\n Single linked list ");
		printf("\n 1.Insert ");
		printf("\n 2.Delete ");
	    printf("\n 3.Display ");
		printf("\n 4.Exit ");	
		printf("\n Enter Your Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: deleteNode();
			break;
			case 3: display();
			break;
			case 4: printf("\n program is terminating ");
			return 0;
			break;
		}
	}
	return 0;
}
void insert()  
{  
    struct node *nn,*temp;  
    
    nn = (struct node*)malloc(sizeof(struct node));      
    if(nn == NULL)  
    {  
        printf("\nOVERFLOW");     
    }  
    else  
    {  
        printf("\nEnter value?\n");  
        scanf("%d",&nn->data);  
         
        if(S == NULL)  
        {  
            nn-> Next = NULL;  
            S = nn;  
            printf("\nNode inserted");  
        }  
        else  
        {  
            temp = S;  
            while (temp -> Next != NULL)  
            {  
                temp = temp -> Next;  
            }  
            temp->Next = ptr;  
            nn->Next = NULL;  
            printf("\nNode inserted");  
          
        }  
    }  
}  
void deleteNode()
{
	
}
void display()
{
	if(S == NULL)
	{
		printf("\n linked list is empty ");
	}
	else
	{
		printf("\n nodes in the linked list ");
		for(C = S;C!=NULL;C=C->next)
		{
			printf("%d",C->data);
		}
		getch();
	}
	
}
void display()
{
	if(S == NULL)
	{
		printf("\n linked list is empty ");
	}
	else
	{
		printf("\n nodes in the linked list ");
		for(C = S;C!=NULL;C=C->next)
		{
			printf("%d",C->data);
		}
		getch();
	}
	
}
